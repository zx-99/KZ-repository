# %% [markdown]
# <center><h1>QBUS6860 - Visual Data Analytics</h1></center>

# %% [markdown]
# # Tutorial 5:   Education by Country
#
# ## The Better Solution

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# ## Loading the data with pandas

# %%
data=pd.read_csv('education-by-country.csv', thousands=',')
data.head()
# Out:
#          country  t_education_percent  population2021
# 0         Canada                56.71       38067.903
# 1          Japan                51.44      126050.804
# 2         Israel                50.92        8789.774
# 3    South Korea                47.74       51305.186
# 4  United States                46.36      332915.073

# %% [markdown]
# ## Drawing the bar plot by matplotlib

# %%
l = []
countries = data['country']
  
share_educated = data['t_education_percent']
  
plt.xlabel("Country")
plt.ylabel("Percentage of People with Tertiary Education")
plt.title("Percentage of People with Tertiary Education by Country in 2021")
  
    
plt.xticks(rotation=90)
      
plt.bar(countries, share_educated)
# Out:
# <BarContainer object of 17 artists>

# %% [markdown]
# ### Why is this better than the previous plot?
#
# ### An alternative is the Lolipop plot

# %%
l = []
countries = data['country']
  
share_educated = data['t_education_percent']

ordered_df = df.sort_values(by='t_education_percent', ascending=False)
  
# Make the plot
plt.xlabel("Country")
plt.ylabel("Percentage of People with Tertiary Education")
plt.title("Percentage of People with Tertiary Education by Country in 2021")
  
    
plt.xticks(np.arange(17),df['country'], rotation=90)
plt.stem(ordered_df['t_education_percent'])
# Out:
# <StemContainer object of 3 artists>
